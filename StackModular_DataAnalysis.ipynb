# %%
import pyodbc
import seaborn as sns
import pandas as pd

# %%
server = 'ALFRED' 
database = 'ConstructionData' 
username = ''
password = 'ConstructionData'  
driver = "SQL Server"
connection_string = 'Driver={};Server={};Database={};Trusted_Connection=True;'.format(driver, server,database)

# %%
conexion = pyodbc.connect(connection_string)
cursor = conexion.cursor()
# select 26 rows from SQL table to insert in dataframe.
query = "SELECT * from BOQ"
df = pd.read_sql(query, conexion)
print(df.head(26))
# Out:
#          Item BOQ     Location  Pour    Item Code            Material  \
# 0   11.1.3.a.1_01  Bottom Slab   SB1  STR-01XL_01            Blinding
# 1   11.1.3.a.1_01     Sump Pit  SB1a  STR-01XL_01            Blinding
# 2      11.1.3.a.2  Bottom Slab   SB1     STR-02XL            Concrete
# 3      11.1.3.a.2     Sump Pit  SB1a     STR-02XL            Concrete
# 4   11.1.3.a.2_01       Cradle   SB1  STR-02XL_01            Concrete
# 5      11.1.3.a.3  Bottom Slab   SB1       STR-05               Steel
# 6      11.1.3.a.3         None   SB5       STR-05               Steel
# 7      11.1.3.a.3         None   SB5       STR-05               Steel
# 8      11.1.3.a.3         None   SB5       STR-05               Steel
# 9      11.1.3.a.3         None   SB5       STR-05               Steel
# 10     11.1.3.a.3     Sump Pit   SB1       STR-05               Steel
# 11     11.1.3.a.3       Cradle   SB1       STR-05               Steel
# 12     11.1.3.a.4  Bottom Slab   SB1       STR-09  Formworks-Vertical
# 13     11.1.3.a.4       Cradle   SB1       STR-09  Formworks-Vertical
# 14     11.1.3.a.6  Bottom Slab   SB1       STR-20                WP-1
# 15  11.1.3.a.7_01  Bottom Slab   SB1       STR-11                WP-2
# 16     11.1.3.a.7  Bottom Slab   SB1       STR-12                WP-3
# 17  11.1.3.a.1_01  Bottom Slab   SB2  STR-01XL_01            Blinding
# 18     11.1.3.a.2  Bottom Slab   SB2     STR-02XL            Concrete
# 19  11.1.3.a.2_01       Cradle   SB2  STR-02XL_01            Concrete
# 20     11.1.3.a.3  Bottom Slab   SB2       STR-05               Steel
# 21     11.1.3.a.3         None   SB5       STR-05               Steel
# 22     11.1.3.a.3         None   SB5       STR-05               Steel
# 23     11.1.3.a.3         None   SB5       STR-05               Steel
# 24     11.1.3.a.3         None   SB5       STR-05               Steel
# 25     11.1.3.a.3       Cradle   SB2       STR-05               Steel
#
#                                           Description Remark Unit  \
# 0   Supply and delivery Blinding concrete fc = 10 ...   None   m3
# 1   Supply and delivery Blinding concrete fc = 10 ...   None   m3
# 2   Supply and delivery Reinforced concrete fc = 5...   None   m3
# 3   Supply and delivery Reinforced concrete fc = 5...   None   m3
# 4   Supply and delivery Reinforced concrete fc = 5...   None   m3
# 5   Supply and delivery Steel reinforcement Grade ...   None   Kg
# 6   Supply and delivery Steel reinforcement Grade ...   None   Kg
# 7   Supply and delivery Steel reinforcement Grade ...   None   Kg
# 8   Supply and delivery Steel reinforcement Grade ...   None   Kg
# 9   Supply and delivery Steel reinforcement Grade ...   None   Kg
# 10  Supply and delivery Steel reinforcement Grade ...   None   Kg
# 11  Supply and delivery Steel reinforcement Grade ...   None   Kg
# 12                        Formworks vertical straight   None   m2
# 13                        Formworks vertical straight   None   m2
# 14  Waterproofing membrane for underground box and...   None   m2
# 15  Waterproofing membrane for formed box structur...   None   m2
# 16  Waterproofing membrane for box structure and e...   None   m2
# 17  Supply and delivery Blinding concrete fc = 10 ...   None   m3
# 18  Supply and delivery Reinforced concrete fc = 5...   None   m3
# 19  Supply and delivery Reinforced concrete fc = 5...   None   m3
# 20  Supply and delivery Steel reinforcement Grade ...   None   Kg
# 21  Supply and delivery Steel reinforcement Grade ...   None   Kg
# 22  Supply and delivery Steel reinforcement Grade ...   None   Kg
# 23  Supply and delivery Steel reinforcement Grade ...   None   Kg
# 24  Supply and delivery Steel reinforcement Grade ...   None   Kg
# 25  Supply and delivery Steel reinforcement Grade ...   None   Kg
#
#           FDR Qty    REAL Qty  Exectuted Qty     Excuted % Execution Date  \
# 0       26.240775   26.240775           30.0  1.1432589167           None
# 1        6.130041    6.130041            NaN                         None
# 2      596.298360  492.360000            NaN                         None
# 3       50.134179   29.640000            NaN                         None
# 4      172.026032   89.030000            NaN                         None
# 5   101025.012050         NaN            NaN                         None
# 6             NaN         NaN            NaN                         None
# 7             NaN         NaN            NaN                         None
# 8             NaN         NaN            NaN                         None
# 9             NaN         NaN            NaN                         None
# 10   10271.217953         NaN            NaN                         None
# 11    9426.272040         NaN            NaN                         None
# 12     106.969080  106.969080            NaN                         None
# 13     103.668414  103.668414            NaN                         None
# 14      51.061881   51.061881            NaN                         None
# 15       0.000000    0.000000            NaN                         None
# 16     405.384728  405.384728            NaN                         None
# 17      34.506218   34.506218            NaN                         None
# 18     773.311580  687.700000            NaN                         None
# 19     139.722871    0.000000            NaN                         None
# 20  130738.250889         NaN            NaN                         None
# 21            NaN         NaN            NaN                         None
# 22            NaN         NaN            NaN                         None
# 23            NaN         NaN            NaN                         None
# 24            NaN         NaN            NaN                         None
# 25    7656.191686    0.000000            NaN                         None
#
#    Execution Period  Remaining Qty Exceded Qty Month  Year
# 0              None            NaN   -3.759225
# 1              None            NaN        None  None  None
# 2              None    -596.298360
# 3              None     -50.134179
# 4              None    -172.026032
# 5              None -101025.012050
# 6              None            NaN              None  None
# 7              None            NaN              None  None
# 8              None            NaN              None  None
# 9              None            NaN              None  None
# 10             None            NaN        None  None  None
# 11             None            NaN        None  None  None
# 12             None    -106.969080
# 13             None            NaN        None  None  None
# 14             None     -51.061881
# 15             None            NaN
# 16             None    -405.384728
# 17             None     -34.506218
# 18             None    -773.311580
# 19             None            NaN
# 20             None -130738.250889
# 21             None            NaN              None  None
# 22             None            NaN              None  None
# 23             None            NaN              None  None
# 24             None            NaN              None  None
# 25             None            NaN        None  None  None
# C:\Users\alfre\AppData\Local\Temp\ipykernel_340\154756816.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conexion)

# %%
df
# Out:
#          Item BOQ     Location  Pour    Item Code            Material  \
# 0   11.1.3.a.1_01  Bottom Slab   SB1  STR-01XL_01            Blinding
# 1   11.1.3.a.1_01     Sump Pit  SB1a  STR-01XL_01            Blinding
# 2      11.1.3.a.2  Bottom Slab   SB1     STR-02XL            Concrete
# 3      11.1.3.a.2     Sump Pit  SB1a     STR-02XL            Concrete
# 4   11.1.3.a.2_01       Cradle   SB1  STR-02XL_01            Concrete
# ..            ...          ...   ...          ...                 ...
# 91     11.1.3.a.4  Bottom Slab   SB6       STR-09  Formworks-Vertical
# 92     11.1.3.a.4       Cradle   SB6       STR-09  Formworks-Vertical
# 93     11.1.3.a.6  Bottom Slab   SB6       STR-20                WP-1
# 94  11.1.3.a.7_01  Bottom Slab   SB6       STR-11                WP-2
# 95     11.1.3.a.7  Bottom Slab   SB6       STR-12                WP-3
#
#                                           Description Remark Unit     FDR Qty  \
# 0   Supply and delivery Blinding concrete fc = 10 ...   None   m3   26.240775
# 1   Supply and delivery Blinding concrete fc = 10 ...   None   m3    6.130041
# 2   Supply and delivery Reinforced concrete fc = 5...   None   m3  596.298360
# 3   Supply and delivery Reinforced concrete fc = 5...   None   m3   50.134179
# 4   Supply and delivery Reinforced concrete fc = 5...   None   m3  172.026032
# ..                                                ...    ...  ...         ...
# 91                        Formworks vertical straight   None   m2   67.401788
# 92                        Formworks vertical straight   None   m2   23.324730
# 93  Waterproofing membrane for underground box and...   None   m2    0.000000
# 94  Waterproofing membrane for formed box structur...   None   m2    0.000000
# 95  Waterproofing membrane for box structure and e...   None   m2  419.022723
#
#       REAL Qty  Exectuted Qty     Excuted % Execution Date Execution Period  \
# 0    26.240775           30.0  1.1432589167           None             None
# 1     6.130041            NaN                         None             None
# 2   492.360000            NaN                         None             None
# 3    29.640000            NaN                         None             None
# 4    89.030000            NaN                         None             None
# ..         ...            ...           ...            ...              ...
# 91   67.401788            NaN                         None             None
# 92   23.324730            NaN                         None             None
# 93    0.000000            NaN                         None             None
# 94    0.000000            NaN                         None             None
# 95  419.022723            NaN                         None             None
#
#     Remaining Qty Exceded Qty Month  Year
# 0             NaN   -3.759225
# 1             NaN        None  None  None
# 2     -596.298360
# 3      -50.134179
# 4     -172.026032
# ..            ...         ...   ...   ...
# 91     -67.401788
# 92            NaN        None  None  None
# 93            NaN
# 94            NaN
# 95    -419.022723
#
# [96 rows x 18 columns]

# %%
df.isnull().sum(axis=0)
# Out:
# Item BOQ             0
# Location            24
# Pour                 0
# Item Code            0
# Material             0
# Description          0
# Remark              96
# Unit                 0
# FDR Qty             24
# REAL Qty            36
# Exectuted Qty       95
# Excuted %            0
# Execution Date      96
# Execution Period    96
# Remaining Qty       61
# Exceded Qty         22
# Month               47
# Year                47
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Item BOQ          96 non-null     object
#  1   Location          72 non-null     object
#  2   Pour              96 non-null     object
#  3   Item Code         96 non-null     object
#  4   Material          96 non-null     object
#  5   Description       96 non-null     object
#  6   Remark            0 non-null      object
#  7   Unit              96 non-null     object
#  8   FDR Qty           72 non-null     float64
#  9   REAL Qty          60 non-null     float64
#  10  Exectuted Qty     1 non-null      float64
#  11  Excuted %         96 non-null     object
#  12  Execution Date    0 non-null      object
#  13  Execution Period  0 non-null      object
#  14  Remaining Qty     35 non-null     float64
#  15  Exceded Qty       74 non-null     object
#  16  Month             49 non-null     object
#  17  Year              49 non-null     object
# dtypes: float64(4), object(14)
# memory usage: 13.6+ KB

# %%
df[df['Location']=='Bottom Slab'].sum()
# Out:
# Item BOQ            11.1.3.a.1_0111.1.3.a.211.1.3.a.311.1.3.a.411....
# Location            Bottom SlabBottom SlabBottom SlabBottom SlabBo...
# Pour                SB1SB1SB1SB1SB1SB1SB1SB2SB2SB2SB2SB2SB2SB2SB3S...
# Item Code           STR-01XL_01STR-02XLSTR-05STR-09STR-20STR-11STR...
# Material            BlindingConcreteSteelFormworks-VerticalWP-1WP-...
# Description         Supply and delivery Blinding concrete fc = 10 ...
# Remark                                                              0
# Unit                m3m3Kgm2m2m2m2m3m3Kgm2m2m2m2m3m3Kgm2m2m2m2m3m3...
# FDR Qty                                                 600875.643486
# REAL Qty                                                  6801.758102
# Exectuted Qty                                                    30.0
# Excuted %                                                1.1432589167
# Execution Date                                                      0
# Execution Period                                                    0
# Remaining Qty                                          -600849.402711
# Exceded Qty                                                 -3.759225
# Month
# Year
# dtype: object

# %%
df.isnull().sum()
# Out:
# Item BOQ             0
# Location            24
# Pour                 0
# Item Code            0
# Material             0
# Description          0
# Remark              96
# Unit                 0
# FDR Qty             24
# REAL Qty            36
# Exectuted Qty       95
# Excuted %            0
# Execution Date      96
# Execution Period    96
# Remaining Qty       61
# Exceded Qty         22
# Month               47
# Year                47
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df['Location'].isnull()]
# Out:
#       Item BOQ Location Pour Item Code Material  \
# 6   11.1.3.a.3     None  SB5    STR-05    Steel
# 7   11.1.3.a.3     None  SB5    STR-05    Steel
# 8   11.1.3.a.3     None  SB5    STR-05    Steel
# 9   11.1.3.a.3     None  SB5    STR-05    Steel
# 21  11.1.3.a.3     None  SB5    STR-05    Steel
# 22  11.1.3.a.3     None  SB5    STR-05    Steel
# 23  11.1.3.a.3     None  SB5    STR-05    Steel
# 24  11.1.3.a.3     None  SB5    STR-05    Steel
# 37  11.1.3.a.3     None  SB5    STR-05    Steel
# 38  11.1.3.a.3     None  SB5    STR-05    Steel
# 39  11.1.3.a.3     None  SB5    STR-05    Steel
# 40  11.1.3.a.3     None  SB5    STR-05    Steel
# 54  11.1.3.a.3     None  SB5    STR-05    Steel
# 55  11.1.3.a.3     None  SB5    STR-05    Steel
# 56  11.1.3.a.3     None  SB5    STR-05    Steel
# 57  11.1.3.a.3     None  SB5    STR-05    Steel
# 69  11.1.3.a.3     None  SB5    STR-05    Steel
# 70  11.1.3.a.3     None  SB5    STR-05    Steel
# 71  11.1.3.a.3     None  SB5    STR-05    Steel
# 72  11.1.3.a.3     None  SB5    STR-05    Steel
# 85  11.1.3.a.3     None  SB5    STR-05    Steel
# 86  11.1.3.a.3     None  SB5    STR-05    Steel
# 87  11.1.3.a.3     None  SB5    STR-05    Steel
# 88  11.1.3.a.3     None  SB5    STR-05    Steel
#
#                                           Description Remark Unit  FDR Qty  \
# 6   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 7   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 8   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 9   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 21  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 22  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 23  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 24  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 37  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 38  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 39  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 40  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 54  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 55  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 56  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 57  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 69  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 70  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 71  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 72  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 85  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 86  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 87  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 88  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
#
#     REAL Qty  Exectuted Qty Excuted % Execution Date Execution Period  \
# 6        NaN            NaN                     None             None
# 7        NaN            NaN                     None             None
# 8        NaN            NaN                     None             None
# 9        NaN            NaN                     None             None
# 21       NaN            NaN                     None             None
# 22       NaN            NaN                     None             None
# 23       NaN            NaN                     None             None
# 24       NaN            NaN                     None             None
# 37       NaN            NaN                     None             None
# 38       NaN            NaN                     None             None
# 39       NaN            NaN                     None             None
# 40       NaN            NaN                     None             None
# 54       NaN            NaN                     None             None
# 55       NaN            NaN                     None             None
# 56       NaN            NaN                     None             None
# 57       NaN            NaN                     None             None
# 69       NaN            NaN                     None             None
# 70       NaN            NaN                     None             None
# 71       NaN            NaN                     None             None
# 72       NaN            NaN                     None             None
# 85       NaN            NaN                     None             None
# 86       NaN            NaN                     None             None
# 87       NaN            NaN                     None             None
# 88       NaN            NaN                     None             None
#
#     Remaining Qty Exceded Qty Month  Year
# 6             NaN              None  None
# 7             NaN              None  None
# 8             NaN              None  None
# 9             NaN              None  None
# 21            NaN              None  None
# 22            NaN              None  None
# 23            NaN              None  None
# 24            NaN              None  None
# 37            NaN              None  None
# 38            NaN              None  None
# 39            NaN              None  None
# 40            NaN              None  None
# 54            NaN              None  None
# 55            NaN              None  None
# 56            NaN              None  None
# 57            NaN              None  None
# 69            NaN              None  None
# 70            NaN              None  None
# 71            NaN              None  None
# 72            NaN              None  None
# 85            NaN              None  None
# 86            NaN              None  None
# 87            NaN              None  None
# 88            NaN              None  None

# %%
df[df['Location'].isnull()]
# Out:
#       Item BOQ Location Pour Item Code Material  \
# 6   11.1.3.a.3     None  SB5    STR-05    Steel
# 7   11.1.3.a.3     None  SB5    STR-05    Steel
# 8   11.1.3.a.3     None  SB5    STR-05    Steel
# 9   11.1.3.a.3     None  SB5    STR-05    Steel
# 21  11.1.3.a.3     None  SB5    STR-05    Steel
# 22  11.1.3.a.3     None  SB5    STR-05    Steel
# 23  11.1.3.a.3     None  SB5    STR-05    Steel
# 24  11.1.3.a.3     None  SB5    STR-05    Steel
# 37  11.1.3.a.3     None  SB5    STR-05    Steel
# 38  11.1.3.a.3     None  SB5    STR-05    Steel
# 39  11.1.3.a.3     None  SB5    STR-05    Steel
# 40  11.1.3.a.3     None  SB5    STR-05    Steel
# 54  11.1.3.a.3     None  SB5    STR-05    Steel
# 55  11.1.3.a.3     None  SB5    STR-05    Steel
# 56  11.1.3.a.3     None  SB5    STR-05    Steel
# 57  11.1.3.a.3     None  SB5    STR-05    Steel
# 69  11.1.3.a.3     None  SB5    STR-05    Steel
# 70  11.1.3.a.3     None  SB5    STR-05    Steel
# 71  11.1.3.a.3     None  SB5    STR-05    Steel
# 72  11.1.3.a.3     None  SB5    STR-05    Steel
# 85  11.1.3.a.3     None  SB5    STR-05    Steel
# 86  11.1.3.a.3     None  SB5    STR-05    Steel
# 87  11.1.3.a.3     None  SB5    STR-05    Steel
# 88  11.1.3.a.3     None  SB5    STR-05    Steel
#
#                                           Description Remark Unit  FDR Qty  \
# 6   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 7   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 8   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 9   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 21  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 22  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 23  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 24  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 37  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 38  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 39  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 40  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 54  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 55  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 56  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 57  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 69  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 70  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 71  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 72  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 85  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 86  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 87  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 88  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
#
#     REAL Qty  Exectuted Qty Excuted % Execution Date Execution Period  \
# 6        NaN            NaN                     None             None
# 7        NaN            NaN                     None             None
# 8        NaN            NaN                     None             None
# 9        NaN            NaN                     None             None
# 21       NaN            NaN                     None             None
# 22       NaN            NaN                     None             None
# 23       NaN            NaN                     None             None
# 24       NaN            NaN                     None             None
# 37       NaN            NaN                     None             None
# 38       NaN            NaN                     None             None
# 39       NaN            NaN                     None             None
# 40       NaN            NaN                     None             None
# 54       NaN            NaN                     None             None
# 55       NaN            NaN                     None             None
# 56       NaN            NaN                     None             None
# 57       NaN            NaN                     None             None
# 69       NaN            NaN                     None             None
# 70       NaN            NaN                     None             None
# 71       NaN            NaN                     None             None
# 72       NaN            NaN                     None             None
# 85       NaN            NaN                     None             None
# 86       NaN            NaN                     None             None
# 87       NaN            NaN                     None             None
# 88       NaN            NaN                     None             None
#
#     Remaining Qty Exceded Qty Month  Year
# 6             NaN              None  None
# 7             NaN              None  None
# 8             NaN              None  None
# 9             NaN              None  None
# 21            NaN              None  None
# 22            NaN              None  None
# 23            NaN              None  None
# 24            NaN              None  None
# 37            NaN              None  None
# 38            NaN              None  None
# 39            NaN              None  None
# 40            NaN              None  None
# 54            NaN              None  None
# 55            NaN              None  None
# 56            NaN              None  None
# 57            NaN              None  None
# 69            NaN              None  None
# 70            NaN              None  None
# 71            NaN              None  None
# 72            NaN              None  None
# 85            NaN              None  None
# 86            NaN              None  None
# 87            NaN              None  None
# 88            NaN              None  None

# %%
df[df['Location'].isnull()]
# Out:
#       Item BOQ Location Pour Item Code Material  \
# 6   11.1.3.a.3     None  SB5    STR-05    Steel
# 7   11.1.3.a.3     None  SB5    STR-05    Steel
# 8   11.1.3.a.3     None  SB5    STR-05    Steel
# 9   11.1.3.a.3     None  SB5    STR-05    Steel
# 21  11.1.3.a.3     None  SB5    STR-05    Steel
# 22  11.1.3.a.3     None  SB5    STR-05    Steel
# 23  11.1.3.a.3     None  SB5    STR-05    Steel
# 24  11.1.3.a.3     None  SB5    STR-05    Steel
# 37  11.1.3.a.3     None  SB5    STR-05    Steel
# 38  11.1.3.a.3     None  SB5    STR-05    Steel
# 39  11.1.3.a.3     None  SB5    STR-05    Steel
# 40  11.1.3.a.3     None  SB5    STR-05    Steel
# 54  11.1.3.a.3     None  SB5    STR-05    Steel
# 55  11.1.3.a.3     None  SB5    STR-05    Steel
# 56  11.1.3.a.3     None  SB5    STR-05    Steel
# 57  11.1.3.a.3     None  SB5    STR-05    Steel
# 69  11.1.3.a.3     None  SB5    STR-05    Steel
# 70  11.1.3.a.3     None  SB5    STR-05    Steel
# 71  11.1.3.a.3     None  SB5    STR-05    Steel
# 72  11.1.3.a.3     None  SB5    STR-05    Steel
# 85  11.1.3.a.3     None  SB5    STR-05    Steel
# 86  11.1.3.a.3     None  SB5    STR-05    Steel
# 87  11.1.3.a.3     None  SB5    STR-05    Steel
# 88  11.1.3.a.3     None  SB5    STR-05    Steel
#
#                                           Description Remark Unit  FDR Qty  \
# 6   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 7   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 8   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 9   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 21  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 22  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 23  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 24  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 37  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 38  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 39  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 40  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 54  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 55  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 56  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 57  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 69  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 70  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 71  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 72  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 85  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 86  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 87  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 88  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
#
#     REAL Qty  Exectuted Qty Excuted % Execution Date Execution Period  \
# 6        NaN            NaN                     None             None
# 7        NaN            NaN                     None             None
# 8        NaN            NaN                     None             None
# 9        NaN            NaN                     None             None
# 21       NaN            NaN                     None             None
# 22       NaN            NaN                     None             None
# 23       NaN            NaN                     None             None
# 24       NaN            NaN                     None             None
# 37       NaN            NaN                     None             None
# 38       NaN            NaN                     None             None
# 39       NaN            NaN                     None             None
# 40       NaN            NaN                     None             None
# 54       NaN            NaN                     None             None
# 55       NaN            NaN                     None             None
# 56       NaN            NaN                     None             None
# 57       NaN            NaN                     None             None
# 69       NaN            NaN                     None             None
# 70       NaN            NaN                     None             None
# 71       NaN            NaN                     None             None
# 72       NaN            NaN                     None             None
# 85       NaN            NaN                     None             None
# 86       NaN            NaN                     None             None
# 87       NaN            NaN                     None             None
# 88       NaN            NaN                     None             None
#
#     Remaining Qty Exceded Qty Month  Year
# 6             NaN              None  None
# 7             NaN              None  None
# 8             NaN              None  None
# 9             NaN              None  None
# 21            NaN              None  None
# 22            NaN              None  None
# 23            NaN              None  None
# 24            NaN              None  None
# 37            NaN              None  None
# 38            NaN              None  None
# 39            NaN              None  None
# 40            NaN              None  None
# 54            NaN              None  None
# 55            NaN              None  None
# 56            NaN              None  None
# 57            NaN              None  None
# 69            NaN              None  None
# 70            NaN              None  None
# 71            NaN              None  None
# 72            NaN              None  None
# 85            NaN              None  None
# 86            NaN              None  None
# 87            NaN              None  None
# 88            NaN              None  None

# %%
df[df['Location'].isnull()]
# Out:
#       Item BOQ Location Pour Item Code Material  \
# 6   11.1.3.a.3     None  SB5    STR-05    Steel
# 7   11.1.3.a.3     None  SB5    STR-05    Steel
# 8   11.1.3.a.3     None  SB5    STR-05    Steel
# 9   11.1.3.a.3     None  SB5    STR-05    Steel
# 21  11.1.3.a.3     None  SB5    STR-05    Steel
# 22  11.1.3.a.3     None  SB5    STR-05    Steel
# 23  11.1.3.a.3     None  SB5    STR-05    Steel
# 24  11.1.3.a.3     None  SB5    STR-05    Steel
# 37  11.1.3.a.3     None  SB5    STR-05    Steel
# 38  11.1.3.a.3     None  SB5    STR-05    Steel
# 39  11.1.3.a.3     None  SB5    STR-05    Steel
# 40  11.1.3.a.3     None  SB5    STR-05    Steel
# 54  11.1.3.a.3     None  SB5    STR-05    Steel
# 55  11.1.3.a.3     None  SB5    STR-05    Steel
# 56  11.1.3.a.3     None  SB5    STR-05    Steel
# 57  11.1.3.a.3     None  SB5    STR-05    Steel
# 69  11.1.3.a.3     None  SB5    STR-05    Steel
# 70  11.1.3.a.3     None  SB5    STR-05    Steel
# 71  11.1.3.a.3     None  SB5    STR-05    Steel
# 72  11.1.3.a.3     None  SB5    STR-05    Steel
# 85  11.1.3.a.3     None  SB5    STR-05    Steel
# 86  11.1.3.a.3     None  SB5    STR-05    Steel
# 87  11.1.3.a.3     None  SB5    STR-05    Steel
# 88  11.1.3.a.3     None  SB5    STR-05    Steel
#
#                                           Description Remark Unit  FDR Qty  \
# 6   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 7   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 8   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 9   Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 21  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 22  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 23  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 24  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 37  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 38  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 39  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 40  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 54  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 55  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 56  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 57  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 69  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 70  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 71  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 72  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 85  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 86  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 87  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
# 88  Supply and delivery Steel reinforcement Grade ...   None   Kg      NaN
#
#     REAL Qty  Exectuted Qty Excuted % Execution Date Execution Period  \
# 6        NaN            NaN                     None             None
# 7        NaN            NaN                     None             None
# 8        NaN            NaN                     None             None
# 9        NaN            NaN                     None             None
# 21       NaN            NaN                     None             None
# 22       NaN            NaN                     None             None
# 23       NaN            NaN                     None             None
# 24       NaN            NaN                     None             None
# 37       NaN            NaN                     None             None
# 38       NaN            NaN                     None             None
# 39       NaN            NaN                     None             None
# 40       NaN            NaN                     None             None
# 54       NaN            NaN                     None             None
# 55       NaN            NaN                     None             None
# 56       NaN            NaN                     None             None
# 57       NaN            NaN                     None             None
# 69       NaN            NaN                     None             None
# 70       NaN            NaN                     None             None
# 71       NaN            NaN                     None             None
# 72       NaN            NaN                     None             None
# 85       NaN            NaN                     None             None
# 86       NaN            NaN                     None             None
# 87       NaN            NaN                     None             None
# 88       NaN            NaN                     None             None
#
#     Remaining Qty Exceded Qty Month  Year
# 6             NaN              None  None
# 7             NaN              None  None
# 8             NaN              None  None
# 9             NaN              None  None
# 21            NaN              None  None
# 22            NaN              None  None
# 23            NaN              None  None
# 24            NaN              None  None
# 37            NaN              None  None
# 38            NaN              None  None
# 39            NaN              None  None
# 40            NaN              None  None
# 54            NaN              None  None
# 55            NaN              None  None
# 56            NaN              None  None
# 57            NaN              None  None
# 69            NaN              None  None
# 70            NaN              None  None
# 71            NaN              None  None
# 72            NaN              None  None
# 85            NaN              None  None
# 86            NaN              None  None
# 87            NaN              None  None
# 88            NaN              None  None
